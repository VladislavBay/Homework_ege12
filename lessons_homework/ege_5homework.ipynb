# %%
#1*, 6, 8, 21,  28, 29, 34, 40

# %%
#Тип 5 № 37140
# for n in range (1,1000):
#     n_bin = bin(n)[2:]
#     if n_bin% 2 == 0:
#           = "0" + bin(n)[2:] + "1"
#     else:
#         bin(n)[2:] = "11" + bin(n)[2:] + "11"
#         r = int(n,2)
# if r > 52:
#     print(r)
def f(n):
    n_bin = bin(n)[2:]
    st = str(n)
    if n % 2 != 0:
        n_bin = "11" + n_bin + "11"
    else:
        n_bin = "1" + n_bin + "0"
    return(int(n_bin,2))
# print(f(13))
lst = []
# lst = list(1,2,3,4)
for n in range(1,1000):
    r = f(n)
    if r > 52:
        lst.append(r)
print(min(lst))
# Out:
# 56

# %%
import math 
# def f(x):
#     x = math.radians(x)
#     return math.sin(x)

def f(n):
    n_bin = bin(n)[2:]
    st = str(n)
    if n % 2 != 0:
        n_bin = "11" + n_bin + "11"
    else:
        n_bin = "1" + n_bin + "0"
    return(int(n_bin,2))


# xs = list(range(10,50))
for x in range(0,360):
    y = f(x)
    print(f"{x}\t{y}")
    

# print(x)
# Out:
# 0	4
# 1	31
# 2	12
# 3	63
# 4	24
# 5	119
# 6	28
# 7	127
# 8	48
# 9	231
# 10	52
# 11	239
# 12	56
# 13	247
# 14	60
# 15	255
# 16	96
# 17	455
# 18	100
# 19	463
# 20	104
# 21	471
# 22	108
# 23	479
# 24	112
# 25	487
# 26	116
# 27	495
# 28	120
# 29	503
# 30	124
# 31	511
# 32	192
# 33	903
# 34	196
# 35	911
# 36	200
# 37	919
# 38	204
# 39	927
# 40	208
# 41	935
# 42	212
# 43	943
# 44	216
# 45	951
# 46	220
# 47	959
# 48	224
# 49	967
# 50	228
# 51	975
# 52	232
# 53	983
# 54	236
# 55	991
# 56	240
# 57	999
# 58	244
# 59	1007
# 60	248
# 61	1015
# 62	252
# 63	1023
# 64	384
# 65	1799
# 66	388
# 67	1807
# 68	392
# 69	1815
# 70	396
# 71	1823
# 72	400
# 73	1831
# 74	404
# 75	1839
# 76	408
# 77	1847
# 78	412
# 79	1855
# 80	416
# 81	1863
# 82	420
# 83	1871
# 84	424
# 85	1879
# 86	428
# 87	1887
# 88	432
# 89	1895
# 90	436
# 91	1903
# 92	440
# 93	1911
# 94	444
# 95	1919
# 96	448
# 97	1927
# 98	452
# 99	1935
# 100	456
# 101	1943
# 102	460
# 103	1951
# 104	464
# 105	1959
# 106	468
# 107	1967
# 108	472
# 109	1975
# 110	476
# 111	1983
# 112	480
# 113	1991
# 114	484
# 115	1999
# 116	488
# 117	2007
# 118	492
# 119	2015
# 120	496
# 121	2023
# 122	500
# 123	2031
# 124	504
# 125	2039
# 126	508
# 127	2047
# 128	768
# 129	3591
# 130	772
# 131	3599
# 132	776
# 133	3607
# 134	780
# 135	3615
# 136	784
# 137	3623
# 138	788
# 139	3631
# 140	792
# 141	3639
# 142	796
# 143	3647
# 144	800
# 145	3655
# 146	804
# 147	3663
# 148	808
# 149	3671
# 150	812
# 151	3679
# 152	816
# 153	3687
# 154	820
# 155	3695
# 156	824
# 157	3703
# 158	828
# 159	3711
# 160	832
# 161	3719
# 162	836
# 163	3727
# 164	840
# 165	3735
# 166	844
# 167	3743
# 168	848
# 169	3751
# 170	852
# 171	3759
# 172	856
# 173	3767
# 174	860
# 175	3775
# 176	864
# 177	3783
# 178	868
# 179	3791
# 180	872
# 181	3799
# 182	876
# 183	3807
# 184	880
# 185	3815
# 186	884
# 187	3823
# 188	888
# 189	3831
# 190	892
# 191	3839
# 192	896
# 193	3847
# 194	900
# 195	3855
# 196	904
# 197	3863
# 198	908
# 199	3871
# 200	912
# 201	3879
# 202	916
# 203	3887
# 204	920
# 205	3895
# 206	924
# 207	3903
# 208	928
# 209	3911
# 210	932
# 211	3919
# 212	936
# 213	3927
# 214	940
# 215	3935
# 216	944
# 217	3943
# 218	948
# 219	3951
# 220	952
# 221	3959
# 222	956
# 223	3967
# 224	960
# 225	3975
# 226	964
# 227	3983
# 228	968
# 229	3991
# 230	972
# 231	3999
# 232	976
# 233	4007
# 234	980
# 235	4015
# 236	984
# 237	4023
# 238	988
# 239	4031
# 240	992
# 241	4039
# 242	996
# 243	4047
# 244	1000
# 245	4055
# 246	1004
# 247	4063
# 248	1008
# 249	4071
# 250	1012
# 251	4079
# 252	1016
# 253	4087
# 254	1020
# 255	4095
# 256	1536
# 257	7175
# 258	1540
# 259	7183
# 260	1544
# 261	7191
# 262	1548
# 263	7199
# 264	1552
# 265	7207
# 266	1556
# 267	7215
# 268	1560
# 269	7223
# 270	1564
# 271	7231
# 272	1568
# 273	7239
# 274	1572
# 275	7247
# 276	1576
# 277	7255
# 278	1580
# 279	7263
# 280	1584
# 281	7271
# 282	1588
# 283	7279
# 284	1592
# 285	7287
# 286	1596
# 287	7295
# 288	1600
# 289	7303
# 290	1604
# 291	7311
# 292	1608
# 293	7319
# 294	1612
# 295	7327
# 296	1616
# 297	7335
# 298	1620
# 299	7343
# 300	1624
# 301	7351
# 302	1628
# 303	7359
# 304	1632
# 305	7367
# 306	1636
# 307	7375
# 308	1640
# 309	7383
# 310	1644
# 311	7391
# 312	1648
# 313	7399
# 314	1652
# 315	7407
# 316	1656
# 317	7415
# 318	1660
# 319	7423
# 320	1664
# 321	7431
# 322	1668
# 323	7439
# 324	1672
# 325	7447
# 326	1676
# 327	7455
# 328	1680
# 329	7463
# 330	1684
# 331	7471
# 332	1688
# 333	7479
# 334	1692
# 335	7487
# 336	1696
# 337	7495
# 338	1700
# 339	7503
# 340	1704
# 341	7511
# 342	1708
# 343	7519
# 344	1712
# 345	7527
# 346	1716
# 347	7535
# 348	1720
# 349	7543
# 350	1724
# 351	7551
# 352	1728
# 353	7559
# 354	1732
# 355	7567
# 356	1736
# 357	7575
# 358	1740
# 359	7583

# %%
#Тип 5 № 63054
# def f(n):
#     n_bin = bin(n)[2:]
#     st = str(n_bin)
#     r = (n_bin%4) + st
#     print(int(r,2))
    
# print(f(13))
n_count = []
def f(n):
    n1 = bin(n)[2:] + bin(n%4)[2:]
    r = int(n1,2)

    print(r)
n_max = 0
for i in range (100000):
    n_max = max(n_max , sum(n_count[]))
#print(f(14))
# Out:
# 58
# None

# %%
#6 Тип 5 № 59828
def f(n):
    s=''
    while n>0:
        s+=str(n%3)
        n//=3
    return s[::-1]
for i in range(1,10000):
    s = f(i)
    if i%3 ==0:
        s+=s[-3:]
    else:
        s+= f((i%3)*3)
    s = int(s,3)
    if s > 150:
        print(i)
        break
# Out:
# 9

# %%
#Тип 5 № 59798
def f(n):
    s=''
    while n>0:
        s+=str(n%3)
        n//=3
    return s[::-1]
for i in range(1,1000):
    s = f(i)
    if i%3 != 0:
        s += f((i%3)*5)
    s = int(s,3)
    if s > 146:
        print(i)
        break
# Out:
# 8

# %%
#Тип 5 № 51974

for n in range(16,17):
    n_bin = bin(n)[2:]
    st = str(n)
    if sum(map(int,st)) % 2 == 0:
        n_bin += "0"
    else:
        n_bin += "1"

    # 5.  Результатом работы алгоритма становится десятичная запись полученного числа R.

    # r = int(n_bin,2) # n_bin - 2 запись
    # # r = int(n_bin) # n_bin - 10 запись
    # if r > 1028:
    #     print(r)

# %%
def f(n):
    n_bin = bin(n)[2:]
    st = str(n)
    if sum(map(int,st)) % 2 == 0:
        n_bin+="0"
    else:
        n_bin+="1"
    return int(n_bin,2)
# print(f(f(f(17))))

lst = []
for n in range(1,1000):
    r = f(f(f(n)))
    if r > 1028:
        lst.append(r)
    
print(lst)
print(min(lst))
# Out:
# [1035, 1041, 1054, 1057, 1071, 1072, 1085, 1090, 1100, 1107, 1116, 1126, 1129, 1143, 1144, 1159, 1162, 1173, 1178, 1188, 1195, 1203, 1212, 1219, 1229, 1234, 1247, 1248, 1262, 1265, 1278, 1284, 1291, 1301, 1306, 1317, 1320, 1335, 1336, 1350, 1353, 1363, 1372, 1379, 1389, 1394, 1406, 1409, 1423, 1424, 1439, 1445, 1450, 1460, 1467, 1476, 1481, 1494, 1497, 1511, 1512, 1522, 1533, 1538, 1548, 1555, 1566, 1569, 1583, 1584, 1599, 1600, 1615, 1616, 1630, 1633, 1644, 1651, 1661, 1666, 1677, 1687, 1688, 1702, 1705, 1718, 1723, 1732, 1739, 1749, 1754, 1760, 1775, 1776, 1790, 1793, 1805, 1810, 1820, 1827, 1836, 1846, 1849, 1863, 1864, 1879, 1882, 1893, 1898, 1908, 1915, 1921, 1934, 1937, 1951, 1952, 1965, 1970, 1980, 1987, 1996, 2005, 2010, 2020, 2027, 2036, 2041, 2054, 2057, 2071, 2072, 2082, 2093, 2098, 2108, 2115, 2126, 2129, 2143, 2144, 2159, 2165, 2170, 2180, 2187, 2196, 2200, 2215, 2216, 2230, 2233, 2243, 2252, 2259, 2269, 2274, 2287, 2288, 2302, 2305, 2318, 2324, 2331, 2341, 2346, 2357, 2360, 2375, 2376, 2390, 2393, 2406, 2409, 2423, 2424, 2439, 2442, 2453, 2458, 2468, 2475, 2481, 2494, 2497, 2511, 2512, 
5543, 5544, 5559, 5562, 5573, 5578, 5588, 5595, 5604, 5611, 5621, 5626, 5637, 5640, 5655, 5656, 5670, 5673, 5683, 5692, 5699, 5709, 5714, 5727, 5728, 5742, 5745, 5758, 5764, 5771, 5781, 5786, 5797, 5801, 5814, 5817, 5831, 5832, 5842, 5853, 5858, 5868, 5875, 5886, 5889, 5903, 5904, 5919, 5925, 5930, 5940, 5947, 5956, 5961, 5974, 5977, 5991, 5992, 6001, 6014, 6017, 6031, 6032, 6045, 6050, 6060, 6067, 6076, 6086, 6089, 6103, 6104, 6119, 6122, 6133, 6138, 6148, 6155, 6161, 6174, 6177, 6191, 6192, 6204, 6211, 6221, 6226, 6237, 6247, 6248, 6262, 6265, 6278, 6283, 6292, 6299, 6309, 6314, 6320, 6335, 6336, 6350, 6353, 636 ...
# 1035

# %%
#Тип 5 № 36018
def f(n):
    n_bin = bin(n)[2:]

# %%
for n in range(1,10000):
    n_bin = bin(n)[2:]
    s = n_bin + n_bin[-2]
    s +=
# Out:
#   Cell In[38], line 1
#     for n in range(1,10000):
#                             ^
# SyntaxError: incomplete input

# %%
# 5: 11224  10658  9828  7607

# %%
# 11224
def f(x):
    s = ""
    while x:
        s =str(x%3) + s
        x//=3
    return s
lst = []
for n in range(1,10000):
    b = f(n)
    sm = b.count("1") + b.count("2") * 2
    if sm % 4 == 0:
        b = ("1" + b)[:-2]
    else:
        b += f((sm % 4 )*3)

    r = int(b,3)
    if r > 353:
        lst.append(r)
print(min(lst))
# Out:
# 354

# %%
# 10658
def f(x):
    s = ""
    while x >  0:
        s = str(x%3) + s
        x//=3
    return s

lst = []

for n in range(11,1000):
    s1 = f(n)
    evens = 0
    odds = 0
    for elem in s1:
        if int(elem) % 2 == 0:
            evens += 1
        else:
            odds += 1
    # if s1.count("2") + s1.count("0") > s1.count("1"):
    #     s1  = "22" + s1
    # else:
    #     s1  = "11" + s1
    if evens > odds:
        s1  = "22" + s1)
    else:
        s1  = "11" + s1
    r = int(s1,3)
    if r > 100:
        lst.append(r)
print(min(lst))
# я вообще не понимаю в чем ошибка
# Out:
# 120

# %%
#  7607
lst = []
for n in range(1,1000):
    n_bin = bin(n)[2:]
    if n % 3 ==0:
        n_bin += n_bin[:-3]
    else:
        ost = bin((n % 3) * 3)[2:]
        n_bin = n_bin + ost
    r = int(n_bin,2)
    if r > 76:
        print(n)
        break
# Out:
# 11

# %%
n = 100
n_bin = bin(n)[2:]
print(type(n), n)
print(type(n_bin), n_bin)
print(n_bin[-3:])

for elem in n_bin:
    print(elem, end=' ')
# Out:
# <class 'int'> 100
# <class 'str'> 1100100
# 100
# 1 1 0 0 1 0 0

# %%
# 9828
def f(x):
    s = ""
    while x > 0:
        s = str(x%3) + s

        x = x//3
    return s
lst = []
for n in range(1,100):
    d = f(n)
    if n % 3 == 0:
        d = "1" + d + "02"
    else:
        d = d + f((n%3)*4)
    r = int(d,3)
    if r < 199:
        lst.append(n)
print(max(lst))
# Out:
# 20
